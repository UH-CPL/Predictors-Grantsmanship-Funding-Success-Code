# %%
import gc
import multiprocessing
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from sklearn.feature_selection import RFECV
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
import seaborn as sns
import warnings
from scipy.stats import boxcox
warnings.simplefilter(action='ignore', category=FutureWarning)
from sklearn import metrics
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import precision_recall_fscore_support as prfs
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, recall_score, precision_score

# %%
df = pd.read_csv("../../curated-data/ModelData_new.csv")
df.head(5)
# Out:
#    NASA  TA  EXT  AGR  CS  NT  OP  AV  EM  Task  ...  NP  FA  SR  AP  AR  DWH  \
# 0    24  38    2    8  10   3   8  16  17    26  ...   2   1   1   2   4    2
# 1    17  35    6    9   7   4   8  25  14    31  ...   2   1   1   2   5    2
# 2    20  38    8    8   6   5   7  19  22    29  ...   1   2   1   2   4    2
# 3    16  54    3    7   3   9   6  23  24    16  ...   2   1   0   2   2    2
# 4    18  28    6    4  10   3   8  13  12    35  ...   1   2   1   2   5    1
#
#    DWR  T  DS  Rank
# 0   70  1   1     2
# 1   70  1   1     1
# 2   90  2   2     0
# 3   60  1   2     0
# 4   60  2   1     2
#
# [5 rows x 25 columns]

# %%
# BFI_List = ['EXT', 'AGR', 'CS', 'NT', 'OP']
# df["BFI_SUM"] = df[BFI_List].sum(axis=1)

# CISS_List = ['AV', 'EM', 'Task']
# df["CISS_SUM"] = df[CISS_List].sum(axis=1)

# %%
# df = df.drop(columns=['EXT', 'AGR', 'CS', 'NT', 'OP', 'AV', 'EM', 'Task'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 25 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NASA    398 non-null    int64
#  1   TA      398 non-null    int64
#  2   EXT     398 non-null    int64
#  3   AGR     398 non-null    int64
#  4   CS      398 non-null    int64
#  5   NT      398 non-null    int64
#  6   OP      398 non-null    int64
#  7   AV      398 non-null    int64
#  8   EM      398 non-null    int64
#  9   Task    398 non-null    int64
#  10  H       398 non-null    int64
#  11  RS      398 non-null    int64
#  12  WH      398 non-null    int64
#  13  TWR     398 non-null    int64
#  14  BR      398 non-null    int64
#  15  NP      398 non-null    int64
#  16  FA      398 non-null    int64
#  17  SR      398 non-null    int64
#  18  AP      398 non-null    int64
#  19  AR      398 non-null    int64
#  20  DWH     398 non-null    int64
#  21  DWR     398 non-null    int64
#  22  T       398 non-null    int64
#  23  DS      398 non-null    int64
#  24  Rank    398 non-null    int64
# dtypes: int64(25)
# memory usage: 77.9 KB

# %%
corr = df.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1, center=0, vmin=-1,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
from scipy import stats

# df['TWR'],fitted_lambda = stats.boxcox(df['TWR'] + .01)
# df['DWR'],fitted_lambda = stats.boxcox(df['DWR'] + .01)
# df['CS'], lmbda = boxcox(df['CS'], lmbda=None)
# df['OP'], lmbda = boxcox(df['OP'], lmbda=None)
# df['Task'], lmbda = boxcox(df['Task'], lmbda=None)
# df['AR'],fitted_lambda = stats.boxcox(df['AR'] + .01)

# %%
# print('Distributions of all columns')
# plt.figure(figsize=(30, 30))
# for i, col in enumerate(list(df.columns)[0:24]):
#     if i < 12:
#         plt.subplot(8, 3, i + 1)
#         sns.distplot(df[col], hist = False, kde = True, kde_kws = {'shade': True, 'linewidth': 3})
#         plt.xlabel(df.columns[i], fontsize=14, fontweight='bold')

# %%
# df['TWR'] = np.log(df['TWR'] + 0.001) 
# df['DWR'] = np.log(df['DWR'] + 0.001)

# %%
# print('Distributions of all columns')
# plt.figure(figsize=(30, 30))
# for i, col in enumerate((df.columns)[0:24]):
# # for i in range(12:24):
# #     print(i)
#     if i > 11:
#         plt.subplot(8, 3, i + 1)
#         sns.distplot(df[col],  hist = True, kde = False)
#         plt.xlabel(df.columns[i], fontsize=14, fontweight='bold')

# %%
# df['TWR'], lmbda = boxcox(df['TWR'], lmbda=None)
# df['DWR'], lmbda = boxcox(df['DWR'], lmbda=None)

# %%
from sklearn.model_selection import StratifiedShuffleSplit

split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_index, test_index in split.split(df, df['SR']):
    strat_train_set = df.loc[train_index]
    strat_test_set = df.loc[test_index]

X_train = strat_train_set.drop('SR', axis=1)
Y_train = strat_train_set['SR'].copy()

X_test = strat_test_set.drop('SR', axis=1)
Y_test = strat_test_set['SR'].copy()

# %%
# %%time
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators = 1600, max_features = 'auto', bootstrap = True)
rf.fit(X_train, Y_train)
y_pred = rf.predict(X_test)
y_score = rf.predict_proba(X_test)
conf_mat = pd.DataFrame(confusion_matrix(Y_test, y_pred))
sns.set(font_scale=1.4) # for label size
plot = sns.heatmap(conf_mat, annot=True, annot_kws={"size": 16}) # font size
plot.set(xlabel='Predicted', ylabel='Actual')
plt.show()
# Out:
# Wall time: 2.68 s

# %%
print("Accuracy: ", accuracy_score(Y_test, y_pred))
print("Precision: ", precision_score(Y_test, y_pred))
print("Recall: ", recall_score(Y_test, y_pred))
print("F1: ", f1_score(Y_test, y_pred))
print("Auc Score: ", roc_auc_score(Y_test, y_score[:,1]))
# Out:
# Accuracy:  0.7
# Precision:  0.7222222222222222
# Recall:  0.65
# F1:  0.6842105263157895
# Auc Score:  0.769375

# %%
df_feature_importance = pd.DataFrame(rf.feature_importances_, index=X_train.columns, columns=['feature importance']).sort_values('feature importance', ascending=False)
df_feature_importance
# Out:
#       feature importance
# H               0.080183
# TA              0.072341
# NP              0.071055
# NASA            0.069201
# EM              0.066190
# AV              0.064856
# Task            0.056983
# EXT             0.049425
# TWR             0.048264
# NT              0.047379
# DWR             0.046890
# FA              0.045698
# AGR             0.044149
# OP              0.042594
# CS              0.038874
# Rank            0.034401
# AR              0.031459
# T               0.019184
# DS              0.015884
# BR              0.013833
# DWH             0.013225
# RS              0.012338
# AP              0.009081
# WH              0.006512

# %%
# %matplotlib inline
feature_imp = pd.Series(rf.feature_importances_,index=X_train.columns).sort_values(ascending=False)
# Creating a bar plot
plt.figure(figsize=(16, 6))
sns.barplot(x=feature_imp, y=feature_imp.index)
# Add labels to your graph
plt.xlabel('Feature Importance Score', fontsize=18)
plt.ylabel('Features', fontsize=18)
plt.title("Visualizing Important Features", fontsize=18)
plt.rc('xtick',labelsize=12)
plt.rc('ytick',labelsize=12)
# plt.legend()
plt.show()

# %%
result_df = X_test
result_df['actual'] = Y_test
result_df['prediction'] = y_pred        
result_df.to_csv('../modeling-result/result_df.csv', index=False)

# %%
result_df = result_df[result_df.actual != 0 ]
result_df
# Out:
#      NASA  TA  EXT  AGR  CS  NT  OP  AV  EM  Task  ...  FA  AP  AR  DWH  DWR  \
# 130    29  58    4    7  10   7   6  22  23    29  ...   6   2   5    2   60
# 328    13  33    5    5   6   2   6  20  11    26  ...   3   2   5    2   90
# 187    29  44    6    5   7   5   5  22  26    26  ...   1   1   3    2   90
# 374    18  42    4    4  10   5   8  17  17    30  ...   1   2   2    1   50
# 363    26  49    6    8  10   7   8  14  22    31  ...   6   2   4    2   60
# 223    19  31    6    8   9   2  10  16  22    33  ...   1   2   5    2   70
# 243    15  36    8    8   8   5   5  16  14    33  ...   6   2   2    1   20
# 312    31  45   10   10  10   6   8  30  19    29  ...   3   2   3    2   60
# 274    25  42    8    8  10   8   9  21  15    34  ...   3   2   5    1   30
# 162    21  31   10    9  10   3  10  17  11    33  ...   1   1   1    2   60
# 309    25  42    4   10   8   6  10  26  29    30  ...   6   2   5    2   60
# 92     17  39    8    7   9   6   7  26  21    27  ...   3   2   1    1   50
# 168    18  32    9    7   5   4   9  28  18    27  ...   5   1   2    2   60
# 131    14  29    4    9   6   3   7  12  10    31  ...   2   2   4    1   20
# 132    26  62    2    9   8   9  10  17  32    29  ...   1   2   4    2   90
# 153    11  20    8    4   5   2   6  21   7    33  ...   2   2   5    2   30
# 242    19  41    9    6  10   6   6   8  19    25  ...   5   2   1    1   50
# 367    23  39    5    9   7   4   8   9  14    28  ...   1   2   1    2   60
# 273    26  36    8    7   9   5   9  26  19    32  ...   4   2   4    2   50
# 392    28  34    7   10  10   4   9  24  14    33  ...   2   2   5    2   80
# 253    21  24    6   10   9   2   8  22   8    29  ...   1   2   3    2   90
# 369    17  48    7   10  10   4  10  25  17    30  ...   4   1   3    2   50
# 280    29  43    9    8   6   8   7  29  28    25  ...   6   2   5    2   50
# 173    15  68    5    6   7  10   5  21  31    28  ...   6   1   4    2   50
# 387    14  30    4    8   7   6  10  13  12    27  ...   2   2   5    2   80
# 281    20  49    5    7   7   4   6  25  26    25  ...   1   2   2    2   50
# 352    25  59    2    6  10   6  10  21  28    29  ...   1   2   2    2   60
# 1      17  35    6    9   7   4   8  25  14    31  ...   1   2   5    2   70
# 65     28  48    7    6   9   7  10  16  18    19  ...   5   2   3    2   80
# 254    21  30    8    8   7   5   9  22  14    26  ...   1   2   3    2   90
# 247    20  29    8    8   3   4   8  13  11    28  ...   1   2   1    1   40
# 2      20  38    8    8   6   5   7  19  22    29  ...   2   2   4    2   90
# 266    14  60    6   10   7   3   9  19  16    31  ...   1   2   2    2   80
# 257    24  38    6    6   8   4   5  21  12    29  ...   1   2   3    2   50
# 394    20  32    8    9  10   3   8  21  12    33  ...   2   2   3    1   70
# 229    32  54    7    8   9   9   9  18  29    29  ...   2   2   5    2   40
# 94     19  60    4    8   7  10   8  24  31    17  ...   1   1   2    2   80
# 43     23  38    9    7  10   5   7  25  21    26  ...   1   2   5    2   60
# 191    12  39    9   10   8   5   9  18  12    30  ...   1   2   4    2   70
# 184    32  46    4    6   8   6   5  15  18    34  ...   1   2   5    2   70
#
#      T  DS  Rank  actual  prediction
# 130  1   2     0       1           0
# 328  1   1     2       1           1
# 187  1   2     1       1           0
# 374  2   1     1       1           1
# 363  2   2     2       1           1
# 223  1   1     1       1           0
# 243  2   1     2       1           1
# 312  2   2     2       1           0
# 274  2   1     2       1           1
# 162  2   2     2       1           1
# 309  1   2     0       1           0
# 92   2   1     2       1           1
# 168  2   2     1       1           1
# 131  2   1     2       1           1
# 132  2   2     1       1           0
# 153  2   1     2       1           1
# 242  2   1     2       1           1
# 367  1   1     2       1           1
# 273  1   1     2       1           1
# 392  1   2     2       1           1
# 253  2   2     2       1           1
# 369  1   2     0       1           0
# 280  2   2     2       1           0
# 173  1   2     2       1           1
# 387  1   2     2       1           1
# 281  1   2     0       1           0
# 352  2   2     1       1           0
# 1    1   1     1       1           0
# 65   1   2     2       1           1
# 254  1   2     2       1           1
# 247  2   1     2       1           1
# 2    2   2     0       1           1
# 266  2   1     2       1           1
# 257  2   2     2       1           0
# 394  1   1     2       1           1
# 229  2   2     1       1           0
# 94   1   2     1       1           0
# 43   1   2     2       1           1
# 191  2   2     2       1           1
# 184  2   1     1       1           1
#
# [40 rows x 26 columns]

# %%
# plt.figure(figsize=(30, 30))
# for i, col in enumerate(list(result_df.columns)[0:23]):
#     if i < 12:
#         plt.subplot(8, 3, i + 1)
#         sns.distplot(result_df[col], hist = False, kde = True, kde_kws = {'shade': True, 'linewidth': 3})
#         plt.xlabel(result_df.columns[i], fontsize=14, fontweight='bold')

# %%
# print('Distributions of all columns')
# plt.figure(figsize=(30, 30))
# for i, col in enumerate((result_df.columns)[0:24]):
# # for i in range(12:24):
# #     print(i)
#     if i > 11:
#         plt.subplot(8, 3, i + 1)
#         sns.distplot(result_df[col],  hist = True, kde = False)
#         plt.xlabel(result_df.columns[i], fontsize=14, fontweight='bold')

# %%
# df_buffered = df[['CISS_SUM', 'H', 'TA', 'NASA', 'NP', 'BFI_SUM', 'DWR', 'TWR', 'AR', 'FA', 'Rank', 'DWH', 'SR']].copy()
# df_buffered

# %%
# df_buffered = df[['H', 'TA', 'NP', 'EM', 'NASA', 'AV', 'Task', 'DWR', 'EXT', 'NT', 'TWR', 'AR', 'FA', 'AGR', 'OP', 'CS', 'SR']].copy()
# df_buffered

# %%
# split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
# for train_index, test_index in split.split(df_buffered, df['SR']):
#     strat_train_set = df_buffered.loc[train_index]
#     strat_test_set = df_buffered.loc[test_index]

# X_train = strat_train_set.drop('SR', axis=1)
# Y_train = strat_train_set['SR'].copy()

# X_test = strat_test_set.drop('SR', axis=1)
# Y_test = strat_test_set['SR'].copy()

# %%
# %%time
# from sklearn.ensemble import RandomForestClassifier

# rf = RandomForestClassifier(n_estimators = 2000,
#                                    max_features = 'auto',
#                                    bootstrap = True)
# rf.fit(X_train, Y_train)
# y_pred = rf.predict(X_test)
# y_score = rf.predict_proba(X_test)
# conf_mat = pd.DataFrame(confusion_matrix(Y_test, y_pred))
# sns.set(font_scale=1.4) # for label size
# plot = sns.heatmap(conf_mat, annot=True, annot_kws={"size": 16}) # font size
# plot.set(xlabel='Predicted', ylabel='Actual')
# plt.show()

# %%
# print("Accuracy: ", accuracy_score(Y_test, y_pred))
# print("Precision: ", precision_score(Y_test, y_pred))
# print("Recall: ", recall_score(Y_test, y_pred))
# print("F1: ", f1_score(Y_test, y_pred))
# print("Auc Score: ", roc_auc_score(Y_test, y_score[:,1]))

# %%
# result_df = X_test
# result_df['actual'] = Y_test
# result_df['prediction'] = y_pred          
# result_df.to_csv('modeling-result/result_df.csv', index=False)

# %%
# df_feature_importance = pd.DataFrame(rf.feature_importances_, index=X_train.columns, columns=['feature importance']).sort_values('feature importance', ascending=False)
# df_feature_importance

# %%
# %matplotlib inline
# feature_imp = pd.Series(rf.feature_importances_,index=X_train.columns).sort_values(ascending=False)
# # Creating a bar plot
# plt.figure(figsize=(16, 6))
# sns.barplot(x=feature_imp, y=feature_imp.index)
# # Add labels to your graph
# plt.xlabel('Feature Importance Score', fontsize=18)
# plt.ylabel('Features', fontsize=18)
# plt.title("Visualizing Important Features", fontsize=18)
# plt.rc('xtick',labelsize=12)
# plt.rc('ytick',labelsize=12)
# # plt.legend()
# plt.show()

# %%
# df_buffered = df[['NP', 'DS', 'H', 'RS','FA', 'TA', 'Rank', 'SR']].copy()
# NP + FA + T + TA + RS + H
df_buffered = df[['NP', 'FA', 'T', 'H', 'TA', 'RS', 'SR']].copy()
df_buffered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NP      398 non-null    float64
#  1   FA      398 non-null    float64
#  2   T       398 non-null    float64
#  3   H       398 non-null    float64
#  4   TA      398 non-null    float64
#  5   RS      398 non-null    float64
#  6   SR      398 non-null    int64
# dtypes: float64(6), int64(1)
# memory usage: 21.9 KB

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df_buffered[['NP', 'FA', 'T', 'H', 'TA', 'RS']] = scaler.fit_transform(df_buffered[['NP', 'FA', 'T', 'H', 'TA', 'RS']])
df_buffered
# Out:
#       NP   FA    T         H    TA   RS  SR
# 0    0.5  0.0  0.0  0.198980  0.36  1.0   1
# 1    0.5  0.0  0.0  0.117347  0.30  1.0   1
# 2    0.0  0.2  1.0  0.066327  0.36  1.0   1
# 3    0.5  0.0  0.0  0.076531  0.68  1.0   0
# 4    0.0  0.2  1.0  0.295918  0.16  1.0   1
# ..   ...  ...  ...       ...   ...  ...  ..
# 393  0.0  0.0  1.0  0.132653  0.56  1.0   1
# 394  0.0  0.2  0.0  0.545918  0.24  1.0   1
# 395  0.5  0.0  0.0  0.122449  0.56  1.0   0
# 396  1.0  0.0  0.0  0.117347  0.28  1.0   0
# 397  0.0  0.0  0.0  0.081633  0.24  1.0   0
#
# [398 rows x 7 columns]

# %%
corr = df_buffered.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1, center=0, vmin=-1,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
# df_buffered = df_buffered.astype("category")
# df_buffered.info()
# df_buffered['H'] = df_buffered['H'].astype("float64")
# df_buffered.info()

# %%
# df_buffered.FA.value_counts()

# %%
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_index, test_index in split.split(df_buffered, df['SR']):
    strat_train_set = df_buffered.loc[train_index]
    strat_test_set = df_buffered.loc[test_index]

X_train = strat_train_set.drop('SR', axis=1)
Y_train = strat_train_set['SR'].copy()

X_test = strat_test_set.drop('SR', axis=1)
Y_test = strat_test_set['SR'].copy()

# %%
Y_test
# Out:
# 130    1
# 151    0
# 217    0
# 328    1
# 187    1
#       ..
# 5      0
# 354    0
# 44     0
# 191    1
# 184    1
# Name: SR, Length: 80, dtype: int64

# %%
# %%time
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators = 2000,
                                   max_features = 'auto',
                                   bootstrap = True)
rf.fit(X_train, Y_train)
y_pred = rf.predict(X_test)
y_score = rf.predict_proba(X_test)
conf_mat = pd.DataFrame(confusion_matrix(Y_test, y_pred))
sns.set(font_scale=1.4) # for label size
plot = sns.heatmap(conf_mat, annot=True, annot_kws={"size": 16}) # font size
plot.set(xlabel='Predicted', ylabel='Actual')
plt.show()
# Out:
# Wall time: 2.93 s

# %%
print("Accuracy: ", accuracy_score(Y_test, y_pred))
print("Precision: ", precision_score(Y_test, y_pred))
print("Recall: ", recall_score(Y_test, y_pred))
print("F1: ", f1_score(Y_test, y_pred))
print("Auc Score: ", roc_auc_score(Y_test, y_score[:,1]))
# Out:
# Accuracy:  0.7125
# Precision:  0.7073170731707317
# Recall:  0.725
# F1:  0.7160493827160495
# Auc Score:  0.7418750000000002

# %%
# %matplotlib inline
feature_imp = pd.Series(rf.feature_importances_,index=X_train.columns).sort_values(ascending=False)
# Creating a bar plot
plt.figure(figsize=(16, 6))
sns.barplot(x=feature_imp, y=feature_imp.index)
# Add labels to your graph
plt.xlabel('Feature Importance Score', fontsize=18)
plt.ylabel('Features', fontsize=18)
plt.title("Visualizing Important Features", fontsize=18)
plt.rc('xtick',labelsize=12)
plt.rc('ytick',labelsize=12)
# plt.legend()
plt.show()

# %%
from sklearn.metrics import r2_score, explained_variance_score, mean_absolute_error

# %%
predictions = rf.predict(X_test)
print(f'R^2 score: {r2_score(y_true=Y_test, y_pred=predictions):.2f}')
print(f'MAE score: {mean_absolute_error(y_true=Y_test, y_pred=predictions):.2f}')
print(f'EVS score: {explained_variance_score(y_true=Y_test, y_pred=predictions):.2f}')
rp = sns.regplot(x=Y_test, y=predictions)
# Out:
# R^2 score: -0.15
# MAE score: 0.29
# EVS score: -0.15

# %%
import pickle
with open('proposal_rf.pkl', 'wb') as file:
    pickle.dump(rf, file)

# %%
# rf.predict([[2, 20, 2]])
